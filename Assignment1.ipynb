# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"https://raw.githubusercontent.com/pb2894/Assignment-DS/refs/heads/main/sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df['City'].unique()
# Out:
# array(['C'], dtype=object)

# %%
df.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
df.drop(columns = ['Date'], inplace = True)
df
# Out:
#           Day  SKU City  Volume         BU  Brand       Model  Avg Price  \
# 0    Thursday  M01    C      15    Mobiles  RealU       RU-10      12100
# 1    Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus      10100
# 2    Thursday  M03    C       7    Mobiles   YouM       YM-99      16100
# 3    Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus      20100
# 4    Thursday  M05    C       3    Mobiles   YouM      YM-98        8100
# ..        ...  ...  ...     ...        ...    ...         ...        ...
# 445  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals       1300
# 446  Thursday  L07    C       6  Lifestyle   Viva   W-Western       2600
# 447  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge       1600
# 448  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals       1900
# 449  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes       3100
#
#      Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value
# ...

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
df.hist()
plt.tight_layout()

# %%
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 200

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.barplot(df)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
numerical_columns = [
    "Volume",
    "Avg Price",
    "Total Sales Value",
    "Discount Rate (%)",
    "Discount Amount",
    "Net Sales Value",
]

# %%
df_standardized = df.copy()
df_standardized[numerical_columns] = sc.fit_transform(df[numerical_columns])

# %%
print("Standardized Data:")
display(df_standardized.head())
# Out:
# Standardized Data:
#         Day  SKU City    Volume       BU  Brand       Model  Avg Price  \
# 0  Thursday  M01    C  2.350029  Mobiles  RealU       RU-10   0.091173
# 1  Thursday  M02    C  1.167129  Mobiles  RealU   RU-9 Plus  -0.019570
# 2  Thursday  M03    C  0.457388  Mobiles   YouM       YM-99   0.312659
# 3  Thursday  M04    C  0.220808  Mobiles   YouM  YM-99 Plus   0.534146
# 4  Thursday  M05    C -0.488932  Mobiles   YouM      YM-98   -0.130313
#
#    Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value
# 0           2.925721          -0.830289         3.952816         2.804756
# 1           1.330995          -0.852661         1.849014         1.271026
# 2           1.562775          -1.351631         1.622995         1.545675
# 3           1.719276          -1.949723         1.113807         1.765810
# 4          -0.188452           0.673739         0.227852        -0.227595

# %%
categorical_columns = ["SKU", "City", "Brand", "Model"]
df_encoded = pd.get_dummies(df_standardized, columns=categorical_columns, drop_first=True)

# %%
print("One-Hot Encoded Data:")
display(df_encoded.head())
# Out:
# One-Hot Encoded Data:
#         Day    Volume       BU  Avg Price  Total Sales Value  \
# 0  Thursday  2.350029  Mobiles   0.091173           2.925721
# 1  Thursday  1.167129  Mobiles  -0.019570           1.330995
# 2  Thursday  0.457388  Mobiles   0.312659           1.562775
# 3  Thursday  0.220808  Mobiles   0.534146           1.719276
# 4  Thursday -0.488932  Mobiles  -0.130313          -0.188452
#
#    Discount Rate (%)  Discount Amount  Net Sales Value  SKU_F02  SKU_F03  ...  \
# 0          -0.830289         3.952816         2.804756    False    False  ...
# 1          -0.852661         1.849014         1.271026    False    False  ...
# 2          -1.351631         1.622995         1.545675    False    False  ...
# 3          -1.949723         1.113807         1.765810    False    False  ...
# 4           0.673739         0.227852        -0.227595    False    False  ...
#
#    Model_Vedic Cream  Model_Vedic Oil  Model_Vedic Shampoo  Model_W-Casuals  \
# ...

# %%
df_encoded.to_csv("transformed_dataset.csv", index=False)

# %%
sc.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8248\1708856230.py in ?()
# ----> 1 sc.fit_transform(df)
#
# D:\New folder\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     293     @wraps(f)
#     294     def wrapped(self, X, *args, **kwargs):
# --> 295         data_to_wrap = f(self, X, *args, **kwargs)
#     296         if isinstance(data_to_wrap, tuple):
#     297             # only wrap the first output for cross decomposition
#     298             return_tuple = (
#
# D:\New folder\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1094                 )
#    1095
#    1096         if y is None:
#    1097             # fit method of arity 1 (unsupervised transformation)
# -> 1098             return self.fit(X, **fit_params).transform(X)
#    1099         else:
# ...

# %%
pd.DataFrame(sc.fit_transform(df), columns=df.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8248\1765458082.py in ?()
# ----> 1 pd.DataFrame(sc.fit_transform(df), columns=df.columns)
#
# D:\New folder\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     293     @wraps(f)
#     294     def wrapped(self, X, *args, **kwargs):
# --> 295         data_to_wrap = f(self, X, *args, **kwargs)
#     296         if isinstance(data_to_wrap, tuple):
#     297             # only wrap the first output for cross decomposition
#     298             return_tuple = (
#
# D:\New folder\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1094                 )
#    1095
#    1096         if y is None:
#    1097             # fit method of arity 1 (unsupervised transformation)
# -> 1098             return self.fit(X, **fit_params).transform(X)
# ...

# %%
scaled_data = pd.DataFrame(sc.fit_transform(df), columns=df.columns)
scaled_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8248\2141494406.py in ?()
# ----> 1 scaled_data = pd.DataFrame(sc.fit_transform(df), columns=df.columns)
#       2 scaled_data
#
# D:\New folder\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     293     @wraps(f)
#     294     def wrapped(self, X, *args, **kwargs):
# --> 295         data_to_wrap = f(self, X, *args, **kwargs)
#     296         if isinstance(data_to_wrap, tuple):
#     297             # only wrap the first output for cross decomposition
#     298             return_tuple = (
#
# D:\New folder\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1094                 )
#    1095
#    1096         if y is None:
#    1097             # fit method of arity 1 (unsupervised transformation)
# ...

# %%
scaled_data.descrbe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 scaled_data.descrbe()
#
# NameError: name 'scaled_data' is not defined

# %%
pd.get_dummies(data = df, columns=['Weather'], dtype=int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 pd.get_dummies(data = df, columns=['Weather'], dtype=int)
#
# File D:\New folder\Lib\site-packages\pandas\core\reshape\encoding.py:169, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167     raise TypeError("Input must be a list-like for parameter `columns`")
#     168 else:
# --> 169     data_to_encode = data[columns]
#     171 # validate prefixes and separator to avoid silently dropping cols
#     172 def check_len(item, name: str):
#
# File D:\New folder\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
# ...
